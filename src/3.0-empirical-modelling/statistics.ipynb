# %%
from generator import JAVHModel, JAModel

# %%
modelsJAVH = JAVHModel.load_from_csvs('../../output')
modelsJA = JAModel.load_from_csvs('../../output')

# %%
modelsJAVH[0].paired_t_test(modelsJAVH[1])
# Out:
# Paired t-test results:
# t-statistic: 2.4285
# p-value: 0.9918
# There is no statistically significant evidence that JAVHModel(VH_number=3, JA_number=3, random_seed=42, median mape=7.1167) has lower logmape values (p >= 0.025).
# (np.float64(2.428516195688701), np.float64(0.9917943578971661))
