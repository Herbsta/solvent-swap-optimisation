# %%
from generator import javh_groups
import matplotlib.pyplot as plt

# %%
unique_temperature_counts = [len(set(group['temperature'].tolist())) for group in javh_groups]

plt.figure(figsize=(10, 6))
plt.hist(unique_temperature_counts, bins=20, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Number of Unique Temperatures')
plt.ylabel('Frequency')
plt.title('Histogram of Unique Temperature Counts per Group')
plt.grid(True, alpha=0.3)
plt.show()
