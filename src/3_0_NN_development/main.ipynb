# %%
from data_module import DataProcessor

# %%
system_columns = ['solvent_1','solvent_2','temperature']

dataprocessor = DataProcessor.CreateDataProcessor(
    raw_data_path='curve_fit_results_x_is_7.csv',
    system_columns=system_columns,
    )

# %%
dataprocessor.processed_data
# Out:
#      group_index  solvent_1  solvent_2  compound_id  temperature           J0  \
# 0              6        174        962        10308       308.15  2153.151528
# 1              7        174        962        10308       313.15  2336.648703
# 2              8        174        962        10308       318.15  2548.882734
# 3              9        174        962        10308       323.15  2282.993604
# 4             10        174        962        10308       328.15  2529.439857
# ..           ...        ...        ...          ...          ...          ...
# 734         1188      13387       1031         2662       293.15  -258.637979
# 735         1189      13387       1031         2662       298.15  -304.166492
# 736         1190      13387       1031         2662       303.15  -326.470842
# 737         1191      13387       1031         2662       308.15  -315.707893
# 738         1192      13387       1031         2662       313.15  -423.411101
#
# ...

# %%
dataprocessor.get_column_names_for_split(target=['J0','J1','J2'])[1]
# Out:
# ['J0', 'J1', 'J2']

# %%
data = dataprocessor.split_data(target_columns=['J0','J1','J2'])

# %%
data[0]
# Out:
#      solvent_1_pure  solvent_2_pure            system  \
# 445          0.0086          0.0003   1031-962-278.15
# 493          0.0185          0.0005   3776-962-283.15
# 581          0.0489          0.0534  3776-6342-313.15
# 135          0.0061          0.1156    702-702-308.15
# 198          0.0488          0.0011    702-962-313.15
# ..              ...             ...               ...
# 71           0.2993          0.1935   244-1140-318.15
# 106          0.3362          0.0048   679-7909-298.15
# 270          0.0159          0.0009    702-962-318.15
# 435          0.0510          0.0010   1031-962-323.15
# 102          0.3729          0.0172   679-6569-323.15
#
#      compound_molecular_weight  compound_AM1_dipole  compound_AM1_E  \
# 445                     144.17             2.473912      -38644.125
# 493                     286.40             1.849785      -71179.008
# 581                     183.19             4.128934      -53649.660
# ...
