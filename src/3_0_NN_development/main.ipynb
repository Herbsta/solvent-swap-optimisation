# %%
from data_module import CreateDataProcessor
SYSTEM_COLS = ['solvent_1','solvent_2','temperature','compound_id']

# %%
system_columns = ['solvent_1','solvent_2','temperature']

dataprocessor = CreateDataProcessor(
    raw_data_path='curve_fit_results_x_is_7.csv',
    system_columns=system_columns,
    target_columns=['J0','J1','J2'],
    )

# %%
dataprocessor.processed_data
# Out:
#      group_index  solvent_1  solvent_2  compound_id  temperature           J0  \
# 0              6        174        962        10308       308.15  2153.151528
# 1              7        174        962        10308       313.15  2336.648703
# 2              8        174        962        10308       318.15  2548.882734
# 3              9        174        962        10308       323.15  2282.993604
# 4             10        174        962        10308       328.15  2529.439857
# ..           ...        ...        ...          ...          ...          ...
# 734         1188      13387       1031         2662       293.15  -258.637979
# 735         1189      13387       1031         2662       298.15  -304.166492
# 736         1190      13387       1031         2662       303.15  -326.470842
# 737         1191      13387       1031         2662       308.15  -315.707893
# 738         1192      13387       1031         2662       313.15  -423.411101
#
# ...

# %%
data = dataprocessor.processed_data.copy()

target = ['J0','J1','J2']


features = [name for name in data.columns if name not in ['group_index','solvent_1','solvent_2','compound_id'] + target]
features = [name for name in features if name not in ['rmse','r2','mape','logmape','group_index']]

if 'temperature' in system_columns: features.remove('temperature')

features_df = data[features].copy()
target_df = data[target].copy()

features_df
# Out:
#      solvent_1_pure  solvent_2_pure             system  \
# 0            0.0023          0.0001     174-962-308.15
# 1            0.0026          0.0001     174-962-313.15
# 2            0.0028          0.0001     174-962-318.15
# 3            0.0032          0.0002     174-962-323.15
# 4            0.0035          0.0002     174-962-328.15
# ..              ...             ...                ...
# 734          0.2278          0.0480  13387-1031-293.15
# 735          0.2589          0.0550  13387-1031-298.15
# 736          0.2966          0.0654  13387-1031-303.15
# 737          0.3078          0.0736  13387-1031-308.15
# 738          0.3532          0.0882  13387-1031-313.15
#
#      compound_molecular_weight  compound_AM1_dipole  compound_AM1_E  \
# 0                       195.26             0.462347      -50221.867
# 1                       195.26             0.462347      -50221.867
# 2                       195.26             0.462347      -50221.867
# ...
